# %% [markdown]
# #Banking Application -> ATM Machine

# %% [markdown]
# ***you can use pythontutor.com to visualize the code***

# %%
class AtmMachine:
    def __init__(self):
        self.pin = ""
        self.balance = 0
        # self.menu()  #this will call it self without the user manually typing AtmMachine.menu()

    def menu(self):
        user_input = input(
            """
            Hi how i can help you?

            1. Press 1 to create pin
            2. Press 2 to change pin
            3. Press 3 to check balence 
            4. Press 4 to withdraw 
            5. Anything to exit

            """)

        match user_input:
            case "1":
                self.create_pin()
            case "2":
                pass
            case "3":
                pass
            case "4":
                pass
            case "5":
                pass
            case _:
                print("Invalid Choice")
                exit()

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter Balance: "))
        self.balance = user_balance

        print("Pin Created Successfully")
        self.menu()

# %%
obj = AtmMachine()

# %%
# obj.menu()

# %%
print(obj.balance)
# Out:
# 0

# %%
# Tell which is the function and which is the method 
L = [1,2,3,4]
L.append(6)
len(L)
# Out:
# 5

# %% [markdown]
# # Magic  Methods/Dunder Methods in Opps
# Magic methods and Dunder methods are same its just a name of same thing

# %% [markdown]
# ```__methodname__()```` These are called magic methods

# %% [markdown]
# The project inside the ```___init__()``` will automatically be initiated when the function will be called.
#
# Here ```__init__()``` is a constructor which is a magic method.

# %% [markdown]
# # Why are we using self in side methods of class?
# Because every self is pointing to the same object which is and instance of a particular class.
# Follow the code below

# %%
class WhySelfIsUsed:
    def __init__(self):
        print(id(self))

# %% [markdown]
# now for upper class we will create an object

# %%
obj2 = WhySelfIsUsed()
# Out:
# 2562232849072

# %%
id(obj)
# Out:
# 2562232850752

# %% [markdown]
# As you can see both ids are the same

# %% [markdown]
# # How object access attributes in OOP
# Just like in function we can also give attributes in side the class as well by just writing it after the self attribute.

# %%
class Person:
    def __init__(self, name, country):
        self.name = name           # This is how we will save data in side the constructor.
        self.country = country 
    def greeting(self):
        if self.country.lower() == "india":
            print(f"Namaste {self.name}")
        else:
            print(f"Hello {self.name}")

# %%
# Defining the object of the above class
p = Person("Sumit", "India")

# %%
p.greeting()
# Out:
# Namaste Sumit

# %%
p.name
# Out:
# 'Sumit'

# %% [markdown]
# *** You can create attribute outside of the class ***

# %%
# We dont have a attribute named gender in our class os the following command will throw an error
#p.male

# %%
# But we can add it by simplying assigning outside of the class
p.gender = "male"

# %%
p.gender
# Out:
# 'male'

# %% [markdown]
# # Reference Variable

# %%
id(p)
# Out:
# 2562232847728

# %% [markdown]
# The following code will not work because q is not defined the vice versa will work just fine.

# %%
# p = q 
q = p
id(q)
# Out:
# 2562232847728

# %% [markdown]
# now if i hange q.name it will refleact to p and person itself

# %%
q.name = "nagraj"

# %%
print(q.name)
print(p.name)
# Out:
# nagraj
# nagraj

# %% [markdown]
# # Pass by reference in OOP
# If the function takes class object as an attribute.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# Defining a function 
def greating(Person):
    print(f"Hello i am {Person.name} and I am {Person.age} year old.")

p = Person("Sumit", 12)

greating(p)
# Out:
# Hello i am Sumit and I am 12 year old.

# %% [markdown]
# **You can also return a one specific class function as an object**

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# Defining a function 
def greeting(person):
    print(f"Hello i am {person.name} and I am {person.age} year old.")
    p1 = Person("Alex", 23)
    return p1

# %%
p = Person("baby", 25)

# %%
a = greeting(p)
# Out:
# Hello i am baby and I am 25 year old.

# %%
a.name
# Out:
# 'Alex'

# %%
a.age
# Out:
# 23

# %% [markdown]
# As we can see even if we have changed the name and age and use the greeting function then too we got the name and age of the class object.

# %% [markdown]
# # Multibility of object in OOP

# %%
class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender 

# outside of the class 
def greeting(person):
    person.name = "Alex"
    return person

# %%
p = Person("Sumit", "Male")

# %%
print(id(p))
# Out:
# 2562232848736

# %%
a = greeting(p)

# %% [markdown]
# Here the greeting function is changing a.name from sumit to alex as we have defined in the function

# %%
a.name
# Out:
# 'Alex'

# %%
p.name
# Out:
# 'Alex'

# %%
print(id(p))
# Out:
# 2562232848736

# %% [markdown]
# # Instance variable in OOP
# The variable can store different data in the same variable.

# %%
class Person:
    def __init__(self, name, country):
        self.name = name
        self.country = country

# %%
p1 = Person("Sumit", "India")

# %%
p2 = Person("Alex", "USA")

# %%
p3 = Person("Ahmed", "india")

# %%
print(id(p1), id(p2), id(p3))
# Out:
# 2562232848400 2562232513424 2562232507344

# %%
p1.name
# Out:
# 'Sumit'

# %%
p2.name
# Out:
# 'Alex'

# %%
p3.name
# Out:
# 'Ahmed'

# %% [markdown]
# As we have created one variable as .name still we was able to store 3 different names inside it which is called Instance Variable

# %% [markdown]
# # Encapsulation
# It protects classes form accidental changes or deletions and promotes code reusability and maintainability.

# %% [markdown]
# when ever you will use "__" in front of a variable it will become a private property or can also say class variable. Which means the variable can not be changed from outside of the class.

# %%
class Car:
    def __init__(self):
        self.color = "Red"
        self.__wheels = 4

    def show_wheels(self):
        car_color = self.color
        car_wheels = self.__wheels
        print(f"Car color is {car_color} and no. of wheels are {car_wheels}")

# %%
obj = Car()

# %%
obj.color
# Out:
# 'Red'

# %%
obj.color = "Blue"

# %%
obj.color
# Out:
# 'Blue'

# %% [markdown]
# But in the case of private variable it will not change. And you can not even access the private variable normally try running the follwoing code and observe the error.

# %%
# obj.__wheels

# %%
obj.__wheels = 6

# %%
obj.show_wheels()
# Out:
# Car color is Blue and no. of wheels are 4

# %% [markdown]
# You can see the modified changes are not reflecting to the private variable.

# %% [markdown]
# But you can still access it. Python changes the name internally form `__wheels` to `_Car__wheels`

# %%
obj._Car__wheels
# Out:
# 4

# %% [markdown]
# but through a function it can be access

# %%
obj._Car__wheels = 5

# %%
obj._Car__wheels
# Out:
# 5

# %% [markdown]
# this can only be done in python and in other languages like java and C++ the variable will die but not get created as a new variable.

# %% [markdown]
# ***What is the point of encapuslation if i can modify the variable outside teh class?***
#
# Encapsulation is not about making data impossible to access. its about controlling how it should be accessed.
# The object protects its own state. Thats why its more useful in methods rather then standalone variables we are doing.
# ```python
# account.deposit(5000)
# account.withdraw(400)
# ```
# instead of doing
# ```python
# account.balance = 5000
# ```
# because a method can validate itself
# ```python
# def withdraw(self, amount):
#     if amount <= self.balance:
#         self.balance -= amount
#     else:
#         print("Insufficient balance")
# ```
# this is because of philosophy of python which is
# ***nothing is for private in python everything is for adults***

# %% [markdown]
# ### Setter and Getter Method
#
# ##### Getter Method
# is a method that retrieves the value of private or protected attribute, instead of letting other code access directly.

# %%
class WildAnimals:
    def __init__(self):
        self.color = ""
        self.__legs = 4 # this is a private property
    
    def get_legs(self):
        return self.__legs

# %%
obj = WildAnimals()

# %%
obj.get_legs()
# Out:
# 4

# %% [markdown]
# ##### Setter Method
# Now lets say you want to change that same private variable then we have to take help of setter method.

# %%
class WildAnimal:
    def __init__(self):
        self.color = ""
        self.__legs = 4 # this is a private property
    
    def get_legs(self):
        return self.__legs
    
    def set_legs(self, new_legs):
        if new_legs == int:
            self.__legs = new_legs
        else:
            print("give a number")

# %%
obj = WildAnimal()
obj.set_legs(6)
# Out:
# give a number

# %%
obj.get_legs()
# Out:
# 4

# %% [markdown]
# # Collection of Class Objects in OOP

# %%
class Person:
    def __init__(self, name, country):
        self.name = name
        self.country = country

# %%
p1, p2, p3 = Person("Sumit", "India"), Person("Amit", "UK"), Person("Shivam", "Austrila")

# %% [markdown]
# Can we store collection of class objects in a list

# %%
L = [p1, p2, p3]
print(L)
# Out:
# [<__main__.Person object at 0x0000025490FA9940>, <__main__.Person object at 0x0000025490F55A90>, <__main__.Person object at 0x0000025490F56FD0>]

# %% [markdown]
# It can store the objects but instead of showing the data we stored in the objects it is showing the memory address where it is stored.
#
# to counter this we can use another function ```__repr__(self)``` to cater this problem.

# %%
class Person:
    def __init__(self, name, country):
        self.name = name
        self.country = country 
    
    def __repr__(self):
        return f"{self.name}, {self.country}"

# %%
p1, p2, p3 = Person("Sumit", "India"), Person("Amit", "UK"), Person("Shivam", "Austrila")
L = [p1, p2, p3]
print(L)
# Out:
# [Sumit, India, Amit, UK, Shivam, Austrila]

# %% [markdown]
# or else you can use a loop to print i.name and i .country. it will work just fine

# %% [markdown]
# # Static Variable and Methods inside OOPs
# Static variable is a better way to use instead of instance variable which changes itself everytime the the instance is created.
#
# for example

# %%
class Customers:
    def __init__(self):
        self.name = ""
        self.customer_id = 0
        self.customer_id += 1

# %% [markdown]
# Acrding to the above code everytime a customer will be created the customer_id will increment itself.

# %%
c1 = Customers()
c1.customer_id
# Out:
# 1

# %%
c2 = Customers()
c2.customer_id
# Out:
# 1

# %% [markdown]
# In both cases it is giving us the same id which is not good for our project for that we use **Static variables**.
#
# ## Static Variables
# are defined inside the class not inside the constructor. Which is accessed by the class name even inside the same class.

# %%
class Customers:

    customer_id = 0

    def __init__(self):
        self.name = ""
        self.customer_id = Customers.customer_id
        Customers.customer_id += 1

# %%
c1 = Customers()
c1.customer_id
# Out:
# 0

# %%
Customers.customer_id
# Out:
# 1

# %%
c2 = Customers()
Customers.customer_id
# Out:
# 2

# %%
c2 = Customers()
Customers.customer_id
# Out:
# 3

# %% [markdown]
# if your variable is different every instance you have to make it as a Static variable and if it is same everyinstance you can make it instance variable. Remember that you can create your instance and static variable as a private variable as well.
#
# But for the Static variable specifically.

# %%
class Customers:

    __customer_id = 0

    def __init__(self):
        self.name = ""
        self.customer_id = Customers.__customer_id
        Customers.__customer_id += 1
    
    @staticmethod # These kind of methods are called static methods. This decorator is used to show them.
    def get_customer_id():  # Without self also you can access this because you are using the name of the class in the return statement. And we are not returning any kind of data which is present inside the constructor.
        return Customers.__customer_id

# %%
c1 = Customers()

# %%
Customers.get_customer_id()
# Out:
# 1

# %% [markdown]
# # Aggregation in OOPs with Python
# You create multiple classes inside your software. There will be relationships between different classes. That relation is called Aggregation. Here one class owns another class.

# %%
class Customer:
    def __init__(self, name, gender, address):
        self.name = name
        self.gender = gender 
        self.address = address

# %% [markdown]
# In the above code name and gender are simple variables because they can be in one word. But address is a combination of multiple words which includes City, State, Country with your local address and pin code. for that we can create another class.

# %%
class Address:
    def __init__(self, city, state, country):
        self.city = city
        self.state = state
        self.country = country

# %% [markdown]
# now instead of giveing address as a parameter in the Customer class we will give Address class as a parameter.

# %%
class Customer:
    def __init__(self, name, gender, address):
        self.name = name
        self.gender = gender 
        self.address = address
    
class Address:
    def __init__(self, city, state, country):
        self.city = city
        self.state = state
        self.country = country

# %%
# first we have to initialize the the address to pass it through the Customer object.
add = Address("gwalior","MP","India")
cus = Customer("Sumit", "Male", add) # This is how we can give a class an attribute for another class

# %% [markdown]
# This is called aggeration as the Customer class is able to communicate with the Address class having kind of a relationship between them.
#
# but
#
# if the Address class has any kind of private variable the Customer class will not be able to access it.

# %% [markdown]
# # Inheritance in OOPs with python
# If a class borrows some properties from another class is called in inheritance. But there are some conditions.
# - non private attribute.
# - non private methods.

# %%
class User:
    def __init__(self):
        self.name = "Summit"
        self.gender = "male"

    def login(self):
        print("Login Done")
    
    def register(self):
        print("Regis Done")

# %%
class Student(User):                  # This is how to perform inheritance 
    def __init__(self):
        self.rollno = 20

    def enroll(self):
        print("Enrolled the course!")

# %%
class instructor(User):                  # This is how to perform inheritance 
    def __init__(self):
        self.IdNo = 20

    def enroll(self):
        print("Enrolled the course!")

# %%
s = Student()
s.enroll()
# Out:
# Enrolled the course!

# %%
s.login()
# Out:
# Login Done

# %% [markdown]
# The above proves that the inheritance is working.
#
# But

# %%
# s.name

# %% [markdown]
# The above code will not work as it will say `There is no attribute called name in s` because if both parent and child class has their own constructor then then classed which was called for instance will get priority. As we can see by running the following code.

# %%
s.rollno
# Out:
# 20

# %% [markdown]
# The attributes can also be inherited form the parent class as well.

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside Phone Constructor")
        self.price = price
        self.brand = brand
        self.camera = camera 

    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    pass

s = SmartPhone(20000, "apple", 3)  # Notice all the attributes belongs to parent class
s.buy()
# Out:
# Inside Phone Constructor
# Buying a Phone

# %% [markdown]
# # Method Overriding in OOP

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside Phone Constructor")
        self.price = price
        self.brand = brand
        self.camera = camera 

    def buy(self):                                      # Notice we have same method in child too
        print("Buying a Phone in phone method")

class SmartPhone(Phone):
    def buy(self):                                      # Notice we have same method in parent too        
        print("Buying a Phone in smartPhone method")

s = SmartPhone(20000, "apple", 3)  
s.buy()
# Out:
# Inside Phone Constructor
# Buying a Phone in smartPhone method

# %% [markdown]
# You can see the method inside the child is getting executed

# %% [markdown]
# # Super Keyword
# By the help of super keyword we can use the same method of the parent class with the child class as well.

# %%
# Same example as above 

class Phone:
    def __init__(self, price, brand, camera):
        print("Inside Phone Constructor")
        self.price = price
        self.brand = brand
        self.camera = camera 

    def buy(self):                                      # Notice we have same method in child too
        print("Buying a Phone in phone method")

class SmartPhone(Phone):
    def buy(self):                                      # Notice we have same method in parent too        
        print("Buying a Phone in smartPhone method")

        super().buy()                                   # Here we are using the super keyword

s = SmartPhone(20000, "apple", 3)  
s.buy()
# Out:
# Inside Phone Constructor
# Buying a Phone in smartPhone method
# Buying a Phone in phone method

# %% [markdown]
# ***We can even do this with the attributes of the Parent and the Child class which is very helpful***

# %%
# Same example as above 

class Phone:
    def __init__(self, price, brand, camera):
        print("Inside Phone Constructor")
        self.price = price
        self.brand = brand
        self.camera = camera 

    def buy(self):                                      
        print("Buying a Phone in phone method")

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):# Here we have included all the attributes needed even of parent and child class.
        super().__init__(price, brand, camera)# Here we have specified the attributes which have been borrowed from the parent class.
        self.os = os
        self.ram = ram

        super().buy()                                   

s = SmartPhone(20000, "apple",3 , "iOS", 3)  
s.buy()
# Out:
# Inside Phone Constructor
# Buying a Phone in phone method
# Buying a Phone in phone method

# %% [markdown]
# ## Types of inheritance in OOPs in python
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance
# - Hybrid Inheritance
#
# Till now we have worked with single Inheritance

# %% [markdown]
# # Polymorphism in OOps
# refers to having multiple forms. use of same function name but with different signatures.
# - Method Overriding
# - Method Overloading
# - Operator Overloading
#
# Method Overriding we have covered earlier.
#
# #### Method Overloading

# %%
class Shape:
    def area(self, redius):
        return 3.14*redius**2
    
    def area(self, l,b):
        return(l*b)
    
s = Shape()
s.area(2,4)
# Out:
# 8

# %% [markdown]
# Well in Polymorphism if you define two methods with same name but different set of attributes it will get executed based on the set of inputs you hav provided, like in the above code if you will give one attribute it will calculate the are for circle and if you give two attributes it will calculate the area of rectangle.
#
# but in python this feature does not exist like other languages but it can still be performed.

# %%
class Shape:
    def area(self, radius, b):
        if b == None:
            return 3.14*radius**2
        else:
            return radius*b
    

s = Shape()
s.area(4, None)
# Out:
# 50.24

# %% [markdown]
# #### Operator Overloading
#
# Same operator is using to perform multiple tasks, Like if we use operator with two strings it will concetinate them, with numbers it will add them and for lists it will combine them.

# %%
"Hello" + "World"
# Out:
# 'HelloWorld'

# %%
1 + 2
# Out:
# 3

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# But in python true Pollymorphism is not possible we do this too with the help of some conditions as well.

# %% [markdown]
# # Abstraction in OOP
# is a fundamental concept in Python programming that allows us to simplify complex concepts and focus on the essential details. It hides unnecessary details and exposing only the relevant information to the users.
#
# To use this we have to use a particular class from a particular library

# %%
from abc import ABC, abstractmethod # These are the components that we have to import to use abstract class

# %% [markdown]
# Now the example of the class that we can use

# %%
class BankServer(ABC):
    def database(self):
        print("Connected with the database")

    @abstractmethod                            # This is how to use abstractmethod
    def security(self):
        print("Security Passed")

# %%
class MobileApp(BankServer):
    def mobile_login(self):
        print("Mobile app login successful")

# %% [markdown]
# Now if you create an instance of the class MobileApp and try to run it it will not run without implementation of security method in BankServer.

# %%
# mob = MobileApp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 mob = MobileApp()
#
# TypeError: Can't instantiate abstract class MobileApp without an implementation for abstract method 'security'

# %% [markdown]
# To inherait the BankServer class without any issue in MobileApp there must exist the specified abstract method in the the child class as well

# %%
class MobileApp(BankServer):
    def mobile_login(self):
        print("Mobile app login successful")

    def security(self):
            print("Mobile Security Passed")

# %%
mob = MobileApp()
mob.security()
# Out:
# Mobile Security Passed

# %% [markdown]
# There for the above code is running without any issue this is how Abstraction works in python
